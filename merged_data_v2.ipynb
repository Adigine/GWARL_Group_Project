# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


csv_femlit = "Resources/female_literacy.csv"
csv_malelit = "Resources/male_literacy.csv"
csv_fertility_rate = "Resources/fertility rate.csv"


# Labor force participation rate, female (% of female population ages 15+) 
female_lit = pd.read_csv(csv_femlit)
malelit = pd.read_csv(csv_malelit)
fertility_rate = pd.read_csv(csv_fertility_rate)
fertility_rate.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965  ...    2008  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...   1.764
# 1  SP.DYN.TFRT.IN  7.450  7.450  7.450  7.450  7.450  7.450  ...   6.254
# 2  SP.DYN.TFRT.IN  7.478  7.524  7.563  7.592  7.611  7.619  ...   6.307
# 3  SP.DYN.TFRT.IN  6.489  6.401  6.282  6.133  5.960  5.773  ...   1.650
# 4  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...   1.250
#
#     2009   2010   2011   2012   2013   2014   2015   2016  2017
# ...

# %%
merged_df = pd.merge(female_lit, malelit, how='inner', on=['Country Code'], suffixes=('_flit', '_mlit'))
# merged_df_clean = merged_df.loc[:, )
merged_df = merged_df.dropna(how='all', axis=1)
# merged_df = merged_df.dropna(how='all', axis=0)
merged_df.index = merged_df['Country Code']
merged_df = merged_df[['Country Code', 'Country Name_flit', '1970_flit', '1972_flit', '1973_flit',
       '1974_flit', '1975_flit', '1976_flit', '1977_flit', '1978_flit',
       '1979_flit', '1980_flit', '1981_flit', '1982_flit', '1983_flit',
       '1984_flit', '1985_flit', '1986_flit', '1987_flit', '1988_flit',
       '1989_flit', '1990_flit', '1991_flit', '1992_flit', '1993_flit',
       '1994_flit', '1995_flit', '1996_flit', '1997_flit', '1998_flit',
       '1999_flit', '2000_flit', '2001_flit', '2002_flit', '2003_flit',
       '2004_flit', '2005_flit', '2006_flit', '2007_flit', '2008_flit',
       '2009_flit', '2010_flit', '2011_flit', '2012_flit', '2013_flit',
       '2014_flit', '2015_flit', '2016_flit', '1970_mlit', '1971_mlit',
       '1972_mlit', '1973_mlit', '1974_mlit', '1975_mlit', '1976_mlit',
       '1977_mlit', '1978_mlit', '1979_mlit', '1980_mlit', '1981_mlit',
       '1982_mlit', '1983_mlit', '1984_mlit', '1985_mlit', '1986_mlit',
       '1987_mlit', '1988_mlit', '1989_mlit', '1990_mlit', '1991_mlit',
       '1992_mlit', '1993_mlit', '1994_mlit', '1995_mlit', '1996_mlit',
       '1997_mlit', '1998_mlit', '1999_mlit', '2000_mlit', '2001_mlit',
       '2002_mlit', '2003_mlit', '2004_mlit', '2005_mlit', '2006_mlit',
       '2007_mlit', '2008_mlit', '2009_mlit', '2010_mlit', '2011_mlit',
       '2012_mlit', '2013_mlit', '2014_mlit', '2015_mlit', '2016_mlit']]

merged_df = merged_df.rename(columns={'Country Name_flit': 'Country Name'})
# merged_df.columns


merged_df.to_csv('merged_data.csv')
merged_df
# Out:
#              Country Code                                       Country Name  \
# Country Code
# ABW                   ABW                                              Aruba
# AFG                   AFG                                        Afghanistan
# AGO                   AGO                                             Angola
# ALB                   ALB                                            Albania
# AND                   AND                                            Andorra
# ARB                   ARB                                         Arab World
# ARE                   ARE                               United Arab Emirates
# ARG                   ARG                                          Argentina
# ARM                   ARM                                            Armenia
# ASM                   ASM                                     American Samoa
# ATG                   ATG                                Antigua and Barbuda
# ...

# %%
merged_df2 = merged_df[['1970_flit', '1972_flit', '1973_flit',
       '1974_flit', '1975_flit', '1976_flit', '1977_flit', '1978_flit',
       '1979_flit', '1980_flit', '1981_flit', '1982_flit', '1983_flit',
       '1984_flit', '1985_flit', '1986_flit', '1987_flit', '1988_flit',
       '1989_flit', '1990_flit', '1991_flit', '1992_flit', '1993_flit',
       '1994_flit', '1995_flit', '1996_flit', '1997_flit', '1998_flit',
       '1999_flit', '2000_flit', '2001_flit', '2002_flit', '2003_flit',
       '2004_flit', '2005_flit', '2006_flit', '2007_flit', '2008_flit',
       '2009_flit', '2010_flit', '2011_flit', '2012_flit', '2013_flit',
       '2014_flit', '2015_flit', '2016_flit']]


years = merged_df2.keys()
years
# Out:
# Index(['1970_flit', '1972_flit', '1973_flit', '1974_flit', '1975_flit',
#        '1976_flit', '1977_flit', '1978_flit', '1979_flit', '1980_flit',
#        '1981_flit', '1982_flit', '1983_flit', '1984_flit', '1985_flit',
#        '1986_flit', '1987_flit', '1988_flit', '1989_flit', '1990_flit',
#        '1991_flit', '1992_flit', '1993_flit', '1994_flit', '1995_flit',
#        '1996_flit', '1997_flit', '1998_flit', '1999_flit', '2000_flit',
#        '2001_flit', '2002_flit', '2003_flit', '2004_flit', '2005_flit',
#        '2006_flit', '2007_flit', '2008_flit', '2009_flit', '2010_flit',
#        '2011_flit', '2012_flit', '2013_flit', '2014_flit', '2015_flit',
#        '2016_flit', '1970_mlit', '1971_mlit', '1972_mlit', '1973_mlit',
#        '1974_mlit', '1975_mlit', '1976_mlit', '1977_mlit', '1978_mlit',
#        '1979_mlit', '1980_mlit', '1981_mlit', '1982_mlit', '1983_mlit',
#        '1984_mlit', '1985_mlit', '1986_mlit', '1987_mlit', '1988_mlit',
# ...

# %%
y_axis= merged_df.loc[;, ['1970_flit', '1972_flit', '1973_flit', '1974_flit', '1975_flit',
       '1976_flit', '1977_flit', '1978_flit', '1979_flit', '1980_flit',
       '1981_flit', '1982_flit', '1983_flit', '1984_flit', '1985_flit',
       '1986_flit', '1987_flit', '1988_flit', '1989_flit', '1990_flit',
       '1991_flit', '1992_flit', '1993_flit', '1994_flit', '1995_flit',
       '1996_flit', '1997_flit', '1998_flit', '1999_flit', '2000_flit',
       '2001_flit', '2002_flit', '2003_flit', '2004_flit', '2005_flit',
       '2006_flit', '2007_flit', '2008_flit', '2009_flit', '2010_flit',
       '2011_flit', '2012_flit', '2013_flit', '2014_flit', '2015_flit',
       '2016_flit', '1970_mlit', '1971_mlit', '1972_mlit', '1973_mlit',
       '1974_mlit', '1975_mlit', '1976_mlit', '1977_mlit', '1978_mlit',
       '1979_mlit', '1980_mlit', '1981_mlit', '1982_mlit', '1983_mlit',
       '1984_mlit', '1985_mlit', '1986_mlit', '1987_mlit', '1988_mlit',
       '1989_mlit', '1990_mlit', '1991_mlit', '1992_mlit', '1993_mlit',
       '1994_mlit', '1995_mlit', '1996_mlit', '1997_mlit', '1998_mlit',
       '1999_mlit', '2000_mlit', '2001_mlit', '2002_mlit', '2003_mlit',
       '2004_mlit', '2005_mlit', '2006_mlit', '2007_mlit', '2008_mlit',
       '2009_mlit', '2010_mlit', '2011_mlit', '2012_mlit', '2013_mlit',
       '2014_mlit', '2015_mlit', '2016_mlit']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-de739bdb67ad> in <module>()
#      17        '2004_mlit', '2005_mlit', '2006_mlit', '2007_mlit', '2008_mlit',
#      18        '2009_mlit', '2010_mlit', '2011_mlit', '2012_mlit', '2013_mlit',
# ---> 19        '2014_mlit', '2015_mlit', '2016_mlit']]
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# ...
