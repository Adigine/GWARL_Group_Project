# %%
import pandas as pd
import numpy as np

csv_femlit = "Resources/female_literacy.csv"
csv_malelit = "Resources/male_literacy.csv"
fertility_rate = "Resources/fertility_rate.csv"

# Labor force participation rate, female (% of female population ages 15+) 
female_lit = pd.read_csv(csv_femlit)
malelit = pd.read_csv(csv_malelit)

female_lit
# Out:
#                                                    Country Name\tCountry Code\tIndicator Name\tIndicator Code\t1960\t1961\t1962\t1963\t1964\t1965\t1966\t1967\t1968\t1969\t1970\t1971\t1972\t1973\t1974\t1975\t1976\t1977\t1978\t1979\t1980\t1981\t1982\t1983\t1984\t1985\t1986\t1987\t1988\t1989\t1990\t1991\t1992\t1993\t1994\t1995\t1996\t1997\t1998\t1999\t2000\t2001\t2002\t2003\t2004\t2005\t2006\t2007\t2008\t2009\t2010\t2011\t2012\t2013\t2014\t2015\t2016\t2017
# Aruba\tABW\t"Literacy rate                           adult female (% of females ages 15 and above)...
# Afghanistan\tAFG\t"Literacy rate                     adult female (% of females ages 15 and above)...
# Angola\tAGO\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Albania\tALB\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Andorra\tAND\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Arab World\tARB\t"Literacy rate                      adult female (% of females ages 15 and above)...
# United Arab Emirates\tARE\t"Literacy rate            adult female (% of females ages 15 and above)...
# Argentina\tARG\t"Literacy rate                       adult female (% of females ages 15 and above)...
# Armenia\tARM\t"Literacy rate                         adult female (% of females ages 15 and above)...
# American Samoa\tASM\t"Literacy rate                  adult female (% of females ages 15 and above)...
# Antigua and Barbuda\tATG\t"Literacy rate             adult female (% of females ages 15 and above)...
# Australia\tAUS\t"Literacy rate                       adult female (% of females ages 15 and above)...
# Austria\tAUT\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Azerbaijan\tAZE\t"Literacy rate                      adult female (% of females ages 15 and above)...
# Burundi\tBDI\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Belgium\tBEL\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Benin\tBEN\t"Literacy rate                           adult female (% of females ages 15 and above)...
# Burkina Faso\tBFA\t"Literacy rate                    adult female (% of females ages 15 and above)...
# Bangladesh\tBGD\t"Literacy rate                      adult female (% of females ages 15 and above)...
# Bulgaria\tBGR\t"Literacy rate                        adult female (% of females ages 15 and above)...
# Bahrain\tBHR\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Bahamas, The\tBHS\t"Literacy rate                    adult female (% of females ages 15 and above)...
# Bosnia and Herzegovina\tBIH\t"Literacy rate          adult female (% of females ages 15 and above)...
# Belarus\tBLR\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Belize\tBLZ\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Bermuda\tBMU\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Bolivia\tBOL\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Brazil\tBRA\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Barbados\tBRB\t"Literacy rate                        adult female (% of females ages 15 and above)...
# Brunei Darussalam\tBRN\t"Literacy rate               adult female (% of females ages 15 and above)...
# ...                                                                                               ...
# Latin America & the Caribbean (IDA & IBRD count...   adult female (% of females ages 15 and above)...
# Timor-Leste\tTLS\t"Literacy rate                     adult female (% of females ages 15 and above)...
# Middle East & North Africa (IDA & IBRD countrie...   adult female (% of females ages 15 and above)...
# Tonga\tTON\t"Literacy rate                           adult female (% of females ages 15 and above)...
# South Asia (IDA & IBRD)\tTSA\t"Literacy rate         adult female (% of females ages 15 and above)...
# Sub-Saharan Africa (IDA & IBRD countries)\tTSS\...   adult female (% of females ages 15 and above)...
# Trinidad and Tobago\tTTO\t"Literacy rate             adult female (% of females ages 15 and above)...
# Tunisia\tTUN\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Turkey\tTUR\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Tuvalu\tTUV\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Tanzania\tTZA\t"Literacy rate                        adult female (% of females ages 15 and above)...
# Uganda\tUGA\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Ukraine\tUKR\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Upper middle income\tUMC\t"Literacy rate             adult female (% of females ages 15 and above)...
# Uruguay\tURY\t"Literacy rate                         adult female (% of females ages 15 and above)...
# United States\tUSA\t"Literacy rate                   adult female (% of females ages 15 and above)...
# Uzbekistan\tUZB\t"Literacy rate                      adult female (% of females ages 15 and above)...
# St. Vincent and the Grenadines\tVCT\t"Literacy ...   adult female (% of females ages 15 and above)...
# Venezuela, RB\tVEN\t"Literacy rate                   adult female (% of females ages 15 and above)...
# British Virgin Islands\tVGB\t"Literacy rate          adult female (% of females ages 15 and above)...
# Virgin Islands (U.S.)\tVIR\t"Literacy rate           adult female (% of females ages 15 and above)...
# Vietnam\tVNM\t"Literacy rate                         adult female (% of females ages 15 and above)...
# Vanuatu\tVUT\t"Literacy rate                         adult female (% of females ages 15 and above)...
# World\tWLD\t"Literacy rate                           adult female (% of females ages 15 and above)...
# Samoa\tWSM\t"Literacy rate                           adult female (% of females ages 15 and above)...
# Kosovo\tXKX\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Yemen, Rep.\tYEM\t"Literacy rate                     adult female (% of females ages 15 and above)...
# South Africa\tZAF\t"Literacy rate                    adult female (% of females ages 15 and above)...
# Zambia\tZMB\t"Literacy rate                          adult female (% of females ages 15 and above)...
# Zimbabwe\tZWE\t"Literacy rate                        adult female (% of females ages 15 and above)...
#
# [264 rows x 1 columns]

# %%
merged_df = pd.merge(labor_df, primary_ed_df, how='inner', on=['Country Code'])
# merged_df_clean = merged_df.loc[:, )
merged_df_clean = merged_df.dropna(how='all', axis=1)
# merged_df
merged_df_clean = merged_df_clean[['Country Name_x', 'Country Code', 'Indicator Name_x', 'Indicator Name_y', 
        '1998_x', '1999_x', '2000_x', '2001_x',
       '2002_x', '2003_x', '2004_x', '2005_x', '2006_x', '2007_x', '2008_x',
       '2009_x', '2010_x', '2011_x', '2012_x', '2013_x', '2014_x', '2015_x',
       '2016_x', '1998_y', '1999_y', '2000_y', '2001_y', '2002_y', '2003_y',
       '2004_y', '2005_y', '2006_y', '2007_y', '2008_y', '2009_y', '2010_y',
       '2011_y', '2012_y', '2013_y', '2014_y', '2015_y', '2016_y']]
# merged_df_clean = merged_df_clean[['Country Name_x', 'Country Code', 'Indicator Name_x','Country Name_y', 'Indicator Name_y',
#        'Indicator Code_y', '2000_x', '2005_x', '2010_x', '2015_x', '2000_y', '2005_y', '2010_y','2015_y']]
merged_df_clean = merged_df_clean.dropna(how='all', thresh=30, axis=0)
# merged_df_clean.to_csv('merged_data.csv')
merged_df_clean
